# %% [markdown]
# <a href="https://colab.research.google.com/github/Shashank520/-CODSOFT-internship-task/blob/main/IMDb_India_Movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name - Movie Rating Prediction**

# %% [markdown]
# ##### **Project Type**    - Movie Rating Prediction
# ##### **Contribution**    - Individual
# **Name** - **Hrushikesh Sutar**

# %% [markdown]
# # **DATA SCIENCE INTERNSHIP @ Codsoft**

# %% [markdown]
# # **Project Summary -**  ......Movie Rating Prediction......

# %% [markdown]
# I am very glad to make this project , this project help me to build up my coding skills and making my concept crystal clear.
#
# I am very thankful to **Codsoft** to give such a beautiful projects. In all of those prjects i choosed Movie Rating Prediction because i go through all the columns & statements of the questions they asked in that, it attracted me very much to attempt this project.The primary objective of this project is to analyze the IMDb India Movies dataset to gain insights into the trends and characteristics of Indian cinema over the years. Key aspects of the analysis include exploring movie ratings, release years, genres, and identifying patterns that define the cinematic landscape in India.
#
# **Dataset:**
# The IMDb India Movies dataset, obtained from the IMDb Datasets repository, includes information about Indian movies such as titles, release years, ratings, genres, and more.
#
# **Rows & Column::** There are total 15509 rows and 10 columns.
#
# **In Data collection::** I have found various columns with help of coding which are head(),tail(),describe(),info(),row(),column(). Some of the methods used & some column to be updated and changed here. Some columns has deleted due to duplicate column present in the list & many more things happened, you can easily go through my project.
#
#
# Before visualizing any data from the Dataset we have done data Wrangling here. With the help of this we checked the null value of all the columns.After getting most null value in the columns, i dropped that columns by using "drop method".When we find minimal number of null values, filling those null values with necessary value as per as requirement by using .fillna()
#
# This is the summary of my project, i wish you like it most.

# %% [markdown]
# ![Screenshot 2024-01-09 at 10.00.56 PM.png](data:image/png;base64,...)

# %% [markdown]
# # **GitHub Link -**
#
# https://github.com/hrushi825/CODSOFT-Internship

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Read the CSV file into a DataFrame using 'ISO-8859-1' encoding
df = pd.read_csv('/content/drive/MyDrive/CODSOFT INTERNSHIP/Task 2/IMDb Movies India.csv', encoding='ISO-8859-1')

# Check the first few rows of the dataframe
df.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# ...

# %%
df.tail()
# Out:
#                       Name    Year Duration          Genre  Rating Votes  \
# 15504  Zulm Ko Jala Doonga  (1988)      NaN         Action     4.6    11
# 15505                Zulmi  (1999)  129 min  Action, Drama     4.5   655
# 15506            Zulmi Raj  (2005)      NaN         Action     NaN   NaN
# 15507        Zulmi Shikari  (1988)      NaN         Action     NaN   NaN
# 15508         Zulm-O-Sitam  (1998)  130 min  Action, Drama     6.2    20
#
#             Director           Actor 1         Actor 2        Actor 3
# 15504  Mahendra Shah  Naseeruddin Shah   Sumeet Saigal  Suparna Anand
# 15505     Kuku Kohli      Akshay Kumar  Twinkle Khanna    Aruna Irani
# 15506     Kiran Thej   Sangeeta Tiwari             NaN            NaN
# 15507            NaN               NaN             NaN            NaN
# 15508   K.C. Bokadia        Dharmendra      Jaya Prada    Arjun Sarja

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

print(f'we have total {df.shape[0]} rows and {df.shape[1]} columns.')
# Out:
# we have total 15509 rows and 10 columns.

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.drop_duplicates(inplace=True)
uni_num_of_rows = df.shape[0]
# Lets check unique rows
uni_num_of_rows
# Out:
# 15503

# %%
# now view new dataset
df.reset_index()
# Out:
#        index                                Name    Year Duration  \
# 0          0                                         NaN      NaN
# 1          1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 2          2                         #Homecoming  (2021)   90 min
# 3          3                             #Yaaram  (2019)  110 min
# 4          4                   ...And Once Again  (2010)  105 min
# ...      ...                                 ...     ...      ...
# 15498  15504                 Zulm Ko Jala Doonga  (1988)      NaN
# 15499  15505                               Zulmi  (1999)  129 min
# 15500  15506                           Zulmi Raj  (2005)      NaN
# 15501  15507                       Zulmi Shikari  (1988)      NaN
# 15502  15508                        Zulm-O-Sitam  (1998)  130 min
#
#                  Genre  Rating Votes            Director           Actor 1  \
# 0                Drama     NaN   NaN       J.S. Randhawa          Manmauji
# ...

# %% [markdown]
# # :-Year with best Ratings

# %%
# Load the IMDb India Movies dataset
movies_df = pd.read_csv('/content/drive/MyDrive/CODSOFT INTERNSHIP/Task 2/IMDb Movies India.csv', encoding='ISO-8859-1')

# Group by year and calculate the average rating for each year
average_ratings_by_year = movies_df.groupby('Year')['Rating'].mean()

# Find the year with the highest average rating
best_year = average_ratings_by_year.idxmax()
best_rating = average_ratings_by_year.max()

print(f"The year with the best rating is {best_year} with an average rating of {best_rating:.2f}")
# Out:
# The year with the best rating is (1948) with an average rating of 7.07

# %% [markdown]
# ## :> Does length of movie have any impact with the rating?

# %% [markdown]
# To determine if the length of a movie has any impact on its rating, we can perform a more in-depth analysis by exploring the relationship between the two variables. Here are some steps we can take using Python and pandas:
# If the scatter plot shows a clear trend or pattern, it indicates a potential relationship.The correlation coefficient ranges from -1 to 1. A positive value suggests a positive correlation (as one variable increases, the other tends to increase), and a negative value suggests a negative correlation.A positive value close to 1 suggests a positive correlation (as movie length increases, the rating tends to increase).
# A negative value close to -1 suggests a negative correlation (as movie length increases, the rating tends to decrease).
# A value close to 0 suggests a weak or no linear correlation.

# %%
# Load the IMDb India Movies dataset
movies_df = pd.read_csv('/content/drive/MyDrive/CODSOFT INTERNSHIP/Task 2/IMDb Movies India.csv', encoding='ISO-8859-1')

# Explore the relationship between Length and Rating
sns.scatterplot(x='Duration', y='Rating', data=movies_df)
plt.title('Relationship Between Movie Length and Rating')
plt.xlabel('Duration (minutes)')
plt.ylabel('Rating')
plt.show()
import numpy as np

# Assuming you have two arrays 'duration' and 'rating'
duration = [1, 2, 3, 4, 5]
rating = [3, 4, 2, 5, 1]

# Calculate the correlation coefficient
correlation_coefficient = np.corrcoef(duration, rating)[0, 1]

# Print the correlation coefficient
print(f"Correlation Coefficient between Duration and Rating: {correlation_coefficient:.2f}")

# %% [markdown]
# ## :> Top 10 movies according to rating per year and overall.

# %%
# Convert the "Rating" column to numeric
movies_df['Rating'] = pd.to_numeric(movies_df['Rating'], errors='coerce')

# Find the top 10 movies overall
top_10_overall = movies_df.sort_values(by='Rating', ascending=False).head(10)

# Find the top 10 movies per year
top_10_per_year = movies_df.groupby('Year').apply(lambda group: group.nlargest(10, 'Rating'))

# Print the results
print("Top 10 Movies Overall:")
print(top_10_overall[['Name', 'Rating']])

print("\nTop 10 Movies Per Year:")
print(top_10_per_year[['Year', 'Name', 'Rating']])
# Out:
# Top 10 Movies Overall:
#                       Name  Rating
# 8339       Love Qubool Hai    10.0
# 5410            Half Songs     9.7
# 2563                 Breed     9.6
# 11704             Ram-Path     9.4
# 14222  The Reluctant Crime     9.4
# 6852                  June     9.4
# 5077          Gho Gho Rani     9.4
# 1314          Ashok Vatika     9.3
# 5125           God of gods     9.3
# 12673   Secrets of Sinauli     9.3
#
# Top 10 Movies Per Year:
#                 Year                        Name  Rating
# Year
# (1913) 9473   (1913)            Mohini Bhasmasur     NaN
# (1914) 12575  (1914)            Satyavan Savitri     NaN
# (1915) 3532   (1915)  Death of Narayanrao Peshwa     NaN
# (1917) 8146   (1917)                 Lanka Dahan     6.7
# (1922) 7337   (1922)                       Karna     NaN
# ...              ...                         ...     ...
# (2022) 1921   (2022)         Battle of Saraighat     NaN
#        2221   (2022)                     Bhediya     NaN
# ...

# %% [markdown]
# ## Top ten high average rated genre

# %%
# plot top ten high average rated genre
genre_rate = df.groupby('Genre').agg({'Rating':'mean'}).sort_values(by='Rating', ascending=False)\
                                .reset_index().head(10)

ax = sns.barplot(data=genre_rate, x='Rating', y='Genre', palette='gist_gray')
ax.bar_label(ax.containers[0])
plt.title('Top ten high average rated genre')
plt.show()
# Out:
# <ipython-input-12-307a23edc3f8>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=genre_rate, x='Rating', y='Genre', palette='gist_gray')

# %% [markdown]
# # Number of popular movies released each year.

# %%
# Filter out rows with missing or NaN values in the "Rating" or "Year" columns
movies_df = movies_df.dropna(subset=['Rating', 'Year'])

# Define a threshold for considering movies as popular (you can adjust this threshold)
popularity_threshold = 7.0

# Count the number of popular movies released each year
popular_movies_per_year = movies_df[movies_df['Rating'] >= popularity_threshold].groupby('Year')['Name'].count()

# Print the results
print("Number of Popular Movies Released Each Year:")
print(popular_movies_per_year)
# Out:
# Number of Popular Movies Released Each Year:
# Year
# (1933)     1
# (1934)     1
# (1935)     1
# (1936)     1
# (1937)     1
#           ..
# (2017)    64
# (2018)    79
# (2019)    99
# (2020)    61
# (2021)    38
# Name: Name, Length: 88, dtype: int64

# %%
# Number of movie release per year
year_count = df.groupby('Year').agg({'Name':'count'}).rename(columns={'Name':'count'}).\
                                        sort_values(by='count', ascending=False).reset_index()
plt.figure(figsize=(20,8))
ax = sns.barplot(data=year_count, x='Year', y='count')
ax.bar_label(ax.containers[0])
plt.title('Number of movie releases per year')
plt.xticks(rotation=90)
plt.show()

# %%
import plotly.express as px
import pandas as pd

# Assuming 'df' is your DataFrame with a 'Year' column
# If 'Year' column is not in datetime format, you can convert it:
# df['Year'] = pd.to_datetime(df['Year'], format='%Y')

# Number of movie releases per year
year_count = df['Year'].value_counts().reset_index()
year_count.columns = ['Year', 'Count']

# Create a bar plot using Plotly Express
fig = px.bar(year_count, x='Year', y='Count', title='Number of Movie Releases per Year', labels={'Count': 'Number of Releases', 'Year': 'Release Year'})

# Customize the layout if needed
fig.update_layout(xaxis=dict(tickmode='linear', dtick=1), xaxis_title='Release Year', yaxis_title='Number of Releases')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Counting the number of votes which movies preformed better in rating per year and overall.

# %%
# Find the maximum rating for each year
max_rating_per_year = movies_df.groupby('Year')['Rating'].max()

# Extract the movie names with the maximum rating for each year
top_movies_per_year = movies_df[movies_df.set_index(['Year', 'Rating']).index.isin(max_rating_per_year.items())]

# Find the top movie overall based on maximum rating
top_movie_overall = movies_df.loc[movies_df['Rating'].idxmax()]

# Print the results
print("Top Movie Overall:")
print(top_movie_overall[['Name', 'Year', 'Rating', 'Votes']])

print("\nTop Movie Per Year:")
print(top_movies_per_year[['Name', 'Year', 'Rating', 'Votes']])

# %% [markdown]
# # Average Rating Per Year

# %%
# Average rating per year
year_rating = df.groupby('Year').agg({'Rating': 'mean'}).reset_index().sort_values(by='Rating',
                                                                     ascending=False,
                                                                     )
year_rating['Rating'] = round(year_rating['Rating'],1)

plt.figure(figsize=(25,9))
ax = sns.barplot(data=year_rating, x='Year', y='Rating')
ax.bar_label(ax.containers[0])
plt.title('Average rating per year')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Which director directed the most movies

# %%
# Group by director and count the number of movies directed by each
directors_movies_count = df['Director'].value_counts()

# Get the director with the most movies
most_prolific_director = directors_movies_count.idxmax()
number_of_movies_directed = directors_movies_count.max()

print(f"The director who directed the most movies is {most_prolific_director} with {number_of_movies_directed} movies.")
# Out:
# The director who directed the most movies is Jayant Desai with 58 movies.

# %% [markdown]
# # Top 10 Avg Rating actors

# %%
print(df.columns)
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
# plot top ten high average rating actors
actor1_rate = df.groupby('Actor 1').agg({'Rating':'mean'}).sort_values(by='Rating', ascending=False)\
                                      .reset_index().head(10)

ax = sns.barplot(data=actor1_rate, x='Rating', y='Actor 1', palette='bone')
ax.bar_label(ax.containers[0])
plt.title('Top ten high average rated Actors')
plt.show()

# %% [markdown]
# # Relationship between rating and votes

# %%
sns.scatterplot(data=df, x='Votes', y='Rating', size=0.1, alpha=0.5)
plt.title('Relationship between rating and votes')
plt.show()

# %% [markdown]
# ### Relationship between rating and duration

# %%
sns.scatterplot(data=df, x='Duration', y='Rating', size=0.1, alpha=0.5)
plt.title('Relationship between rating and duration')
plt.show()

# %% [markdown]
# ## Spreadness of rating per year

# %%
plt.figure(figsize=(20,8))
sns.boxplot(data=df, x='Year', y='Rating')
plt.title('Spreadness of rating per year')
plt.xticks(rotation=90)
plt.show()
